# %% [markdown]
# <a href="https://colab.research.google.com/github/fekaprasatia-cmd/PrediksiBitcoin/blob/main/Rancangan_Aplikasi_berbasis_web.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from docx import Document

file_path = '/content/Pengantar untuk Antigravity.docx'
document = Document(file_path)

full_text = []
for para in document.paragraphs:
    full_text.append(para.text)

# Display the entire text from the document
print('\n'.join(full_text))
# Out:
# Ringkasan Proyek: Dashboard Prediksi Harga Bitcoin
# Halo Antigravity! Berikut adalah ringkasan dari percakapan saya dengan Pengguna sebelumnya, agar Anda dapat melanjutkan membantu Pengguna dengan lancar.
# 1. Konteks Proyek
# Pengguna sedang membangun aplikasi dashboard berbasis web menggunakan framework Streamlit (Python). Aplikasi ini dirancang untuk menampilkan hasil prediksi harga Bitcoin berdasarkan model Deep Learning (khususnya Hibrida GRU-LSTM yang dioptimalkan dengan PSO).
# Proyek ini merupakan bagian dari laporan riset (diunggah oleh pengguna) yang berjudul:
# "Optimasi Hibrida GRU-LSTM Berbasis PSO dengan Evaluasi Volatility-Aware untuk Prediksi Harga Bitcoin pada Berbagai Rezim Pasar"
# 2. Apa yang Telah Dikerjakan
# Saya (AI sebelumnya) telah membantu membuat beberapa draf kode, dengan pembaruan terbaru di (app_realtime.py). Berikut rinciannya:
# ...

# %%
# %%writefile app.py
import streamlit as st
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime, timedelta

# --- Page Configuration ---
st.set_page_config(page_title="Dashboard Prediksi Harga Bitcoin", layout="wide")
st.title("📈 Dashboard Prediksi Harga Bitcoin")

# --- Sidebar for controls ---
st.sidebar.header("Pengaturan Dashboard")

# Timeframe selection
today = datetime.now()
start_date = st.sidebar.date_input("Tanggal Mulai Historis", value=today - timedelta(days=365*2), max_value=today)
end_date = st.sidebar.date_input("Tanggal Akhir Historis", value=today, max_value=today)

# Model selection (placeholder for future use)
model_option = st.sidebar.selectbox(
    "Pilih Model Prediksi",
    ("Hybrid GRU-LSTM PSO", "Model Lainnya"),
    disabled=True # Disabled until models are integrated
)

# Prediction Horizon (placeholder)
prediction_horizon = st.sidebar.slider(
    "Horizon Prediksi (hari ke depan)",
    min_value=1,
    max_value=30,
    value=7,
    disabled=True # Disabled until models are integrated
)

# --- Data Fetching ---
@st.cache_data(ttl=600) # Cache data for 10 minutes
def get_bitcoin_data(start, end):
    ticker = yf.Ticker("BTC-USD")
    data = ticker.history(start=start, end=end)
    return data

try:
    df = get_bitcoin_data(start_date, end_date)
    if df.empty:
        st.warning("Tidak ada data Bitcoin yang tersedia untuk rentang tanggal yang dipilih.")
    else:
        st.subheader("Data Historis Harga Bitcoin (BTC-USD)")
        st.dataframe(df[['Open', 'High', 'Low', 'Close', 'Volume']].tail())

        # --- Plotting Historical Data ---
        fig = go.Figure(data=[go.Candlestick(
            x=df.index,
            open=df['Open'],
            high=df['High'],
            low=df['Low'],
            close=df['Close'],
            name='BTC-USD'
        )])
        fig.update_layout(xaxis_rangeslider_visible=False, title_text='Pergerakan Harga Historis BTC-USD')
        st.plotly_chart(fig, use_container_width=True)

        # --- Placeholder for Model Loading and Prediction ---
        st.subheader("Prediksi Harga Bitcoin")
        st.info("Bagian ini adalah placeholder untuk integrasi model Deep Learning Anda.")

        # Example of mocked prediction (as mentioned in the doc)
        # This part will be replaced with actual model loading and prediction logic
        st.write("Pengguna belum sepenuhnya mengintegrasikan model TensorFlow dan fungsi Scaler-nya ke dalam kode ini, meskipun panduannya telah diberikan pada percakapan sebelumnya.")
        st.write("Untuk saat ini, prediksinya adalah simulasi atau mockup. Silakan unggah model `.h5` dan scaler `.pkl` Anda jika Anda ingin saya mengintegrasikannya.")

        # --- Placeholder for Evaluation Metrics ---
        st.subheader("Matriks Evaluasi Model")
        st.info("Bagian ini akan menampilkan metrik evaluasi model Anda (misalnya RMSE, MAE, MAPE, Akurasi).")
        st.write("Saat ini, metriknya adalah hardcoded/simulasi seperti yang disebutkan dalam deskripsi proyek.")
        # Example hardcoded values from the document
        st.markdown("**RMSE:** 2957.25")
        st.markdown("**MAE:** 2438.21")
        st.markdown("**MAPE:** 2.92%")
        st.markdown("**Akurasi:** 97.08%")

except Exception as e:
    st.error(f"Terjadi kesalahan saat memuat data: {e}")

# --- Instructions to run (for Colab environment) ---
# To run this Streamlit app in Google Colab, you would typically save it
# and then use ngrok to expose it. For example:
# !pip install streamlit -q
# !pip install pyngrok -q
# from pyngrok import ngrok
# public_url = ngrok.connect(8501)
# print(f"Streamlit app will be available at: {public_url}")
# !streamlit run app.py &>/dev/null
# Out:
# Overwriting app.py

# %% [markdown]
# Saya telah membuat file `app.py` yang berisi kerangka dasar aplikasi Streamlit Anda. Untuk menjalankannya di Google Colab, Anda perlu menginstal `streamlit` dan `pyngrok`, lalu mengeksposnya menggunakan `ngrok`. Berikut adalah langkah-langkahnya:
#
# 1.  **Instal pustaka yang diperlukan:**
#     ```python
#     !pip install streamlit -q
#     !pip install pyngrok -q
#     ```
# 2.  **Jalankan aplikasi Streamlit dan dapatkan URL publik:**
#     ```python
#     from pyngrok import ngrok
#
#     # Pastikan Anda telah login ke ngrok dan memiliki authtoken yang dikonfigurasi
#     # ngrok.set_auth_token("YOUR_NGROK_AUTHTOKEN") # Ganti dengan token ngrok Anda
#
#     public_url = ngrok.connect(8501)
#     print(f"Streamlit app will be available at: {public_url}")
#
#     # Jalankan aplikasi Streamlit di background
#     !streamlit run app.py &>/dev/null
#     ```
#
# Setelah menjalankan langkah-langkah ini, Anda akan mendapatkan URL yang dapat Anda klik untuk melihat dasbor Streamlit Anda.

# %%
# !pip install streamlit -q
# !pip install pyngrok -q

# %%
from pyngrok import ngrok
import os

# Pastikan Anda telah login ke ngrok dan memiliki authtoken yang dikonfigurasi
# Jika Anda belum memiliki authtoken, daftar di ngrok.com dan masukkan di sini.
NGROK_AUTH_TOKEN = "3GCjpBpaV9iVSelgAtKsENUWlmx_86WFCQ6rhGMebqy9axY7H" # <--- Ini adalah authtoken ngrok Anda
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Connect to ngrok
public_url = ngrok.connect(8501)
print(f"Streamlit app will be available at: {public_url}")

# Run the Streamlit app in the background
# !streamlit run app.py &>/dev/null
# Out:
# Streamlit app will be available at: NgrokTunnel: "https://jalapeno-savanna-overrule.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile app.py
import streamlit as st
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime, timedelta
import numpy as np
import joblib
import tensorflow as tf

# --- Page Configuration ---
st.set_page_config(
    page_title='Bitcoin Intelligence Dashboard',
    page_icon='₿',
    layout='wide',
    initial_sidebar_state='expanded'
)

# --- Custom CSS ---
st.markdown("""
    <style>
    @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;600;800&display=swap');
    html, body, [class*='css'] { font-family: 'Inter', sans-serif; }
    .stApp { background-color: #F7F9FB; }
    div[data-testid='stMetric'] {
        background-color: #ffffff;
        border: 1px solid #ECEFF2;
        border-radius: 15px;
        padding: 15px 25px !important;
        box-shadow: 0 4px 6px rgba(0,0,0,0.02);
    }
    .main-header { font-weight: 800; color: #1A1C1E; font-size: 2.5rem !important; margin-bottom: 0.5rem; }
    .sub-header { color: #64748B; font-size: 1.1rem; margin-bottom: 2rem; }
    .status-badge { padding: 4px 12px; border-radius: 20px; font-size: 0.8rem; font-weight: 600; }
    </style>
""", unsafe_allow_html=True)

# --- Asset Loading ---
@st.cache_resource
def load_assets():
    try:
        custom_objects = {'mse': tf.keras.losses.MeanSquaredError()}
        model = tf.keras.models.load_model('/content/your_model.h5', custom_objects=custom_objects)
        scaler = joblib.load('/content/your_scaler.pkl')
        return model, scaler, None
    except Exception as e: return None, None, str(e)

model, scaler, err = load_assets()

def make_forecast(df, model, scaler, days, n_steps=60):
    try:
        if len(df) < n_steps: return None
        close_prices = df['Close'].values.reshape(-1, 1)

        log_returns = np.diff(np.log(close_prices.flatten()))
        vol_std = np.std(log_returns)

        last_window = close_prices[-n_steps:]
        scaled_input = scaler.transform(last_window)
        current_seq = scaled_input.reshape(1, n_steps, 1)

        preds = []
        current_last_price = close_prices[-1][0]

        for i in range(days):
            p_scaled = model.predict(current_seq, verbose=0)[0, 0]
            p_model = scaler.inverse_transform([[p_scaled]])[0, 0]

            noise_scale = vol_std * 2.5 * (1 + i * 0.05)
            shock = np.random.normal(0, noise_scale)
            p_final = p_model * np.exp(shock)

            p_final = np.clip(p_final, current_last_price * 0.90, current_last_price * 1.10)
            preds.append(p_final)

            current_last_price = p_final
            p_scaled_next = scaler.transform([[p_final]])[0, 0]
            current_seq = np.append(current_seq[:, 1:, :], [[[p_scaled_next]]], axis=1)

        return np.array(preds)
    except:
        return None

# --- Sidebar ---
st.sidebar.image('https://cryptologos.cc/logos/bitcoin-btc-logo.png', width=60)
st.sidebar.markdown('## Crypto Control')
with st.sidebar.expander("📅 Range Waktu Historis", expanded=True):
    start_date = st.date_input('Mulai', value=datetime(2020, 1, 1))
    end_date = st.date_input('Selesai', value=datetime.now())
with st.sidebar.expander("🔮 Forecast Horizon", expanded=True):
    horizon = st.slider('Jumlah Hari Prediksi', 1, 30, 14)

# --- Main UI ---
st.markdown('<h1 class="main-header">Bitcoin Intelligence</h1>', unsafe_allow_html=True)
st.markdown('<p class="sub-header">Data Real-time & Prediksi AI (Balanced Stochastic)</p>', unsafe_allow_html=True)

try:
    df_live = yf.download('BTC-USD', start=start_date, end=end_date, auto_adjust=False)

    if not df_live.empty:
        if isinstance(df_live.columns, pd.MultiIndex):
            df_live.columns = [col[0] for col in df_live.columns]

        latest_price = float(df_live['Close'].iloc[-1])
        prev_price = float(df_live['Close'].iloc[-2])
        delta = ((latest_price - prev_price) / prev_price) * 100

        c1, c2, c3, c4 = st.columns(4)
        c1.metric("Price (Live)", f"${latest_price:,.2f}", f"{delta:+.2f}%")
        c2.metric("24h High", f"${float(df_live['High'].iloc[-1]):,.2f}")
        c3.metric("24h Low", f"${float(df_live['Low'].iloc[-1]):,.2f}")
        status_color = "#28a745" if not err else "#dc3545"
        c4.markdown(f"<div style='text-align:center; padding-top:20px;'><span class='status-badge' style='background:{status_color}22; color:{status_color};'>● {'System Active' if not err else 'Model Error'}</span></div>", unsafe_allow_html=True)

        tab1, tab2, tab3 = st.tabs(['📊 Candlestick & Forecast', '🧪 Evaluation Metrics', '🏗️ Architecture'])

        with tab1:
            if model and scaler:
                preds_res = make_forecast(df_live, model, scaler, horizon)
                if preds_res is not None:
                    future_dates = [df_live.index[-1] + timedelta(days=i+1) for i in range(horizon)]

                    fig = go.Figure()
                    fig.add_trace(go.Candlestick(
                        x=df_live.index[-100:],
                        open=df_live['Open'].iloc[-100:],
                        high=df_live['High'].iloc[-100:],
                        low=df_live['Low'].iloc[-100:],
                        close=df_live['Close'].iloc[-100:],
                        name='Actual Price'
                    ))
                    fig.add_trace(go.Scatter(
                        x=future_dates,
                        y=preds_res,
                        name='AI Forecast (Moderate Stochastic)',
                        line=dict(color='#007bff', width=3, dash='dot')
                    ))

                    fig.update_layout(
                        xaxis_rangeslider_visible=False,
                        template='plotly_white', height=600,
                        title='Analisis Pergerakan Harga & Prediksi Volatilitas'
                    )
                    st.plotly_chart(fig, use_container_width=True)

                    st.markdown("### 🔮 AI Prediction Details")
                    # Gain/Loss calculation: Current Predicted vs Previous Day
                    # For the first day of prediction, compare with latest_price
                    prices_series = np.insert(preds_res, 0, latest_price)
                    pct_changes = np.diff(prices_series) / prices_series[:-1] * 100

                    forecast_df = pd.DataFrame({
                        'Date': future_dates,
                        'Predicted Price (USD)': preds_res,
                        'Gain/Loss (%)': pct_changes
                    })

                    forecast_df['Date'] = forecast_df['Date'].dt.strftime('%d-%m-%Y')
                    forecast_df['Predicted Price (USD)'] = forecast_df['Predicted Price (USD)'].map('${:,.2f}'.format)
                    forecast_df['Gain/Loss (%)'] = forecast_df['Gain/Loss (%)'].map('{:+.2f}%'.format)
                    st.table(forecast_df.set_index('Date'))

        with tab2:
            st.markdown("### Model Performance Metrics")
            m1, m2, m3, m4 = st.columns(4)
            m1.metric("RMSE", "2957.25"); m2.metric("MAE", "2438.21")
            m3.metric("MAPE", "2.92%"); m4.metric("Accuracy", "97.08%")

        with tab3:
            st.markdown("### Arsitektur Hybrid GRU-LSTM PSO")
            st.write("Integrasi Deep Learning untuk analisis volatilitas pasar dengan optimasi Particle Swarm Optimization.")

except Exception as e: st.error(f'Error: {e}')
# Out:
# Overwriting app.py

# %%
# Jalankan sel ini setelah Anda mengunggah file model .h5 dan scaler .pkl Anda ke /content/
from pyngrok import ngrok
import os

# Pastikan authtoken ngrok sudah diatur dari langkah sebelumnya
# NGROK_AUTH_TOKEN = "YOUR_NGROK_AUTHTOKEN"
# ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Pastikan tidak ada tunnel aktif dari sesi sebelumnya untuk menghindari konflik
ngrok.kill()

# Connect to ngrok
public_url = ngrok.connect(8501)
print(f"Streamlit app will be available at: {public_url}")

# Run the Streamlit app in the background
# Menambahkan & disamping !streamlit run app.py &>/dev/null untuk memastikan proses berjalan di background
# !streamlit run app.py &>/dev/null
# Out:
# Streamlit app will be available at: NgrokTunnel: "https://jalapeno-savanna-overrule.ngrok-free.dev" -> "http://localhost:8501"

# %% [markdown]
# Seperti yang saya sebutkan, file `.h5` berisi model Deep Learning yang telah dilatih, dan `.pkl` berisi scaler yang digunakan untuk normalisasi data. Karena saya tidak dapat melatih model secara langsung, saya akan membuat file **placeholder (dummy)** untuk keduanya. Ini memungkinkan Anda untuk menjalankan aplikasi Streamlit dan melihat strukturnya, tetapi prediksinya tidak akan akurat sampai Anda mengunggah dan menggunakan model dan scaler Anda yang sebenarnya.
#
# Berikut adalah kode untuk membuat model Keras dummy dan scaler `MinMaxScaler` dummy, kemudian menyimpannya sebagai `your_model.h5` dan `your_scaler.pkl` di direktori `/content/`.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Buat model Keras dummy
# Ini adalah model yang sangat sederhana dan TIDAK akan memberikan prediksi yang akurat.
# Anda perlu menggantinya dengan model Anda yang sebenarnya.

# Model dummy ini didesain agar kompatibel dengan 'n_steps=60' yang ada di app.py
dummy_model = Sequential([
    LSTM(50, activation='relu', input_shape=(60, 1)),
    Dense(1)
])
dummy_model.compile(optimizer='adam', loss='mse')

# Simpan model dummy ke file .h5
dummy_model.save('/content/your_model.h5')
print("Model dummy 'your_model.h5' telah dibuat di /content/")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model dummy 'your_model.h5' telah dibuat di /content/

# %%
import joblib
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Buat scaler dummy
# Scaler ini hanya sebuah placeholder. Untuk prediksi yang sebenarnya,
# Anda harus menggunakan scaler yang dilatih pada data pelatihan Anda yang sebenarnya.

dummy_scaler = MinMaxScaler(feature_range=(0, 1))
# Fit scaler dengan beberapa data dummy untuk memastikan ia memiliki .scale_ dan .min_ yang benar
# Ini penting agar inverse_transform tidak error.
dummy_scaler.fit(np.array([0, 1, 10, 100]).reshape(-1, 1))

# Simpan scaler dummy ke file .pkl
joblib.dump(dummy_scaler, '/content/your_scaler.pkl')
print("Scaler dummy 'your_scaler.pkl' telah dibuat di /content/")
# Out:
# Scaler dummy 'your_scaler.pkl' telah dibuat di /content/

# %% [markdown]
# **Langkah Selanjutnya:**
#
# Sekarang Anda memiliki file model dan scaler dummy di `/content/`. Anda dapat melanjutkan menjalankan aplikasi Streamlit.
#
# Untuk prediksi yang sebenarnya, **pastikan Anda mengunggah file `your_model.h5` dan `your_scaler.pkl` Anda yang asli** (dengan nama yang sama) ke direktori `/content/` di Google Colab. Setelah diunggah, jalankan kembali sel terakhir (yang menjalankan `streamlit run app.py`) untuk melihat prediksi realtime dengan model Anda.

# %%
# !pip install PyPDF2
import PyPDF2

# Membaca file PDF Project DS3.pdf
pdf_path = '/content/Project DS3.pdf'

try:
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        # Ambil 10 halaman pertama
        for i in range(min(10, len(reader.pages))):
            text += reader.pages[i].extract_text()

    print("Isi PDF berhasil diekstrak. Berikut ringkasannya:")
    print(text[:2000] + "...")
except Exception as e:
    print(f"Terjadi kesalahan saat membaca PDF: {e}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.3 MB/s eta 0:00:00
# ...
# Isi PDF berhasil diekstrak. Berikut ringkasannya:
# JUDUL RISET: “Optimasi Hibrida GRU-LSTM Berbasis PSO dengan Evaluasi Volatility-Aware untuk Prediksi Harga Bitcoin pada
# Berbagai  Rezim Pasar”
# Nama Anggota Kelompok 2 DS 3:
# 1. Fauzan Eka Prasatia NIM. 25.55.2929
# 2. Asnia Viviawaty Biringang NIM. 25.55.2914
# 3. Harry T. Pagiu NIM. 25.55.2913
# 4. Junus Ferianus Ngahu NIM. 25.55.2945
# Tahap 1. Import Library
# # ==========================================
# # IMPORT LIBRARY
# # ==========================================
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import mean_absolute_error
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import GRU, LSTM, Dense, Dropout
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import joblib

# 1. Ambil Data (Juli 2015 - Sekarang)
print("Mengunduh data dari Juli 2015...")
df = yf.download('BTC-USD', start='2015-07-01')
data = df[['Close']].values

# 2. Preprocessing
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

X, y = [], []
n_steps = 60

for i in range(n_steps, len(scaled_data)):
    X.append(scaled_data[i-n_steps:i, 0])
    y.append(scaled_data[i, 0])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# 3. Bangun Model Hybrid GRU-LSTM
print("Membangun model Hybrid GRU-LSTM...")
model = Sequential([
    GRU(units=64, return_sequences=True, input_shape=(n_steps, 1)),
    Dropout(0.2),
    LSTM(units=64, return_sequences=False),
    Dropout(0.2),
    Dense(units=32, activation='relu'),
    Dense(units=1)
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# 4. Latih Model
print("Melatih model dengan rentang data baru (2015-Sekarang)...")
model.fit(X, y, epochs=10, batch_size=32, verbose=1)

# 5. Simpan Hasil
model.save('/content/your_model.h5')
joblib.dump(scaler, '/content/your_scaler.pkl')

print("\nBerhasil! Model dan Scaler telah diperbarui sesuai rentang waktu riset.")
# Out:
# /tmp/ipykernel_1776/2384920949.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('BTC-USD', start='2015-07-01')
# [*********************100%***********************]  1 of 1 completed
# Mengunduh data dari Juli 2015...
# Membangun model Hybrid GRU-LSTM...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Melatih model dengan rentang data baru (2015-Sekarang)...
# Epoch 1/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.0072
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 0.0013
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 0.0010
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 9.4310e-04
# Epoch 5/10
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, LSTM, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
import joblib

# 1. Ambil Data Terbaru
print("Mengunduh data BTC-USD...")
df = yf.download('BTC-USD', start='2015-07-01')
data = df[['Close']].values

# 2. Preprocessing
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

X, y = [], []
n_steps = 60

for i in range(n_steps, len(scaled_data)):
    X.append(scaled_data[i-n_steps:i, 0])
    y.append(scaled_data[i, 0])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# 3. Model Hybrid GRU-LSTM
model = Sequential([
    Input(shape=(n_steps, 1)),
    GRU(units=128, return_sequences=True),
    Dropout(0.2),
    LSTM(units=128, return_sequences=False),
    Dropout(0.2),
    Dense(units=64, activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=1)
])

optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# 4. Latih Model (30 Epochs)
print("Melatih ulang model (30 Epochs)... Silakan tunggu.")
model.fit(X, y, epochs=30, batch_size=64, verbose=1)

# 5. Simpan Model dengan format .keras (Rekomendasi Terbaru)
model.save('/content/your_model.keras')
joblib.dump(scaler, '/content/your_scaler.pkl')

print("\nModel (.keras) dan Scaler (.pkl) telah diperbarui.")
# Out:
# Mengunduh data BTC-USD...
# /tmp/ipykernel_1776/2264617306.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('BTC-USD', start='2015-07-01')
# [*********************100%***********************]  1 of 1 completed
# Melatih ulang model (30 Epochs)... Silakan tunggu.
# Epoch 1/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - loss: 0.0100
# Epoch 2/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 15s 239ms/step - loss: 9.3397e-04
# Epoch 3/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - loss: 8.5227e-04
# Epoch 4/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - loss: 7.7351e-04
# Epoch 5/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 20s 233ms/step - loss: 8.0789e-04
# Epoch 6/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - loss: 7.1630e-04
# Epoch 7/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - loss: 6.7497e-04
# Epoch 8/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 19s 299ms/step - loss: 6.1667e-04
# Epoch 9/30
# ...

# %%
with open('requirements.txt', 'w') as f:
    f.write('streamlit\nyfinance\npandas\nplotly\nnumpy\njoblib\ntensorflow\nscikit-learn')

# %% [markdown]
# ### 🚀 Push Project to GitHub
# Pastikan Anda sudah memiliki **Personal Access Token (classic)** dari GitHub Settings > Developer Settings > Personal access tokens.

# %%
import os

# --- SILAKAN ISI DATA DI BAWAH INI ---
USER_NAME = "fekaprasatia-cmd"
USER_EMAIL = "fauzanekaprasatia@gmail.com" # Masukkan email GitHub Anda
REPO_NAME = "PrediksiBitcoin"
# Cara buat token: Settings -> Developer Settings -> Personal Access Tokens -> Tokens (classic)
GITHUB_TOKEN = "MASUKKAN_TOKEN_ANDA_DI_SINI"

os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
os.environ['USER_NAME'] = USER_NAME
os.environ['USER_EMAIL'] = USER_EMAIL
os.environ['REPO_NAME'] = REPO_NAME

if GITHUB_TOKEN == "MASUKKAN_TOKEN_ANDA_DI_SINI":
    print("❌ ERROR: Harap masukkan GITHUB_TOKEN Anda terlebih dahulu!")
else:
    print("✅ Konfigurasi siap. Lanjut ke sel berikutnya.")
# Out:
# Konfigurasi siap. Jalankan sel berikutnya untuk mengunggah file.

# %%
# %%bash
# cd /content
# git config --global user.email "$USER_EMAIL"
# git config --global user.name "$USER_NAME"
#
# # Bersihkan git lama untuk menghindari konflik
# rm -rf .git
# git init
#
# # Tambahkan file yang ada secara cerdas
# git add app.py requirements.txt your_scaler.pkl
#
# # Tambahkan model (baik format .h5 maupun .keras jika ada)
# [ -f "your_model.keras" ] && git add your_model.keras
# [ -f "your_model.h5" ] && git add your_model.h5
#
# git commit -m "Update dashboard and model files"
# git branch -M main
# git remote add origin https://$GITHUB_TOKEN@github.com/$USER_NAME/$REPO_NAME.git
#
# # Push dengan paksa untuk memastikan file terupdate
# git push -u origin main --force
#
# echo "--- BERHASIL: File Anda sudah masuk ke GitHub ---"
# Out:
# Initialized empty Git repository in /content/.git/
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	AI 2.png
# 	Pengantar untuk Antigravity.docx
# 	Project DS3.pdf
# 	Screenshot 2026-07-08 124105.png
# 	ai prediction.png
# 	app.py
# 	bc.png
# 	fff.png
# 	requirements.txt
# 	sample_data/
# 	your_model.h5
# 	your_scaler.pkl
#
# nothing added to commit but untracked files present (use "git add" to track)
# --- PROSES PUSH SELESAI ---
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# ...
